# %% [markdown]
# Step 1: 4x4 Exponential Array (NumPy)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import pandas as pd
# %matplotlib inline
# Out:
# [[1.25085414 0.31026122 0.58959295 1.37926223]
#  [1.5525202  1.40896314 0.03586149 0.65271217]
#  [0.351483   0.04465006 0.91039002 1.92695197]
#  [0.251458   0.31207462 0.69117381 0.9990766 ]]

# %%
# Set random seed for reproducibility
np.random.seed(42)

# Create 4x4 array from exponential distribution (scale=1 default)
exp_array = np.random.exponential(scale=1.0, size=(4, 4))

print("4x4 Array from Exponential Distribution:")
print(exp_array)
# Out:
# 4x4 Array from Exponential Distribution:
# [[0.46926809 3.01012143 1.31674569 0.91294255]
#  [0.16962487 0.16959629 0.05983877 2.01123086]
#  [0.91908215 1.23125006 0.02079931 3.50355748]
#  [1.78642954 0.23868763 0.20067899 0.20261142]]

# %% [markdown]
#  Step 2: Histogram of Exponential, Uniform, Normal Distributions (Matplotlib)

# %%
# Generate 100,000 samples from exponential, uniform, and normal distributions
exp_data = np.random.exponential(scale=1.0, size=100000)
uniform_data = np.random.rand(100000)
normal_data = np.random.normal(loc=0, scale=1, size=100000)

# Create histogram
plt.figure(figsize=(10, 6))
plt.hist(np.random.rand(100000), density=True, bins=100, histtype="step", color="blue", label="rand")
plt.axis([-2.5, 2.5, 0, 1.1])
plt.legend(loc = "upper left")
plt.title("Random distributions")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# 3. Using matplotlib, plot the Z = X**2 + Y**2 in a 3D plot. Limit the x and y values to [-5, 5]

# %%
# Create meshgrid for X and Y
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)

# Calculate Z = X^2 + Y^2
Z = X**2 + Y**2

# Create 3D plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
surface = ax.plot_surface(X, Y, Z, cmap='viridis')

# Add colorbar and labels
fig.colorbar(surface, ax=ax, shrink=0.5, aspect=5)
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
ax.set_title('3D Plot of Z = X² + Y²')

plt.show()

# %% [markdown]
# 4. Calculate the pearson standard coefficient and spearman rank correlation for the [HP,
# Attack, Defense, Sp. Ark, Sp. Def, Speed] features in the seaborn tutorial.ipynb. Visualize the
# results using heatmaps.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Download the dataset
# !wget -q https://elitedatascience.com/wp-content/uploads/2022/07/Pokemon.csv

# Load the dataset
df = pd.read_csv('Pokemon.csv', index_col=0, encoding='latin')

# Select the relevant features
features = ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']
stats_df = df[features]

# Calculate Pearson correlation
pearson_corr = stats_df.corr(method='pearson')

# Calculate Spearman rank correlation
spearman_corr = stats_df.corr(method='spearman')

# Plot Pearson correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(pearson_corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Pearson Correlation Heatmap')
plt.show()

# Plot Spearman rank correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(spearman_corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Spearman Rank Correlation Heatmap')
plt.show()
